# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import seaborn as sns
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# Import the 3 dimensionality reduction methods
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA


import pickle
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
data = pickle.load(open('../data/SF.pickle','rb'))

# %%
idx = 251

idx_2 = 77

print(data[idx]['class']) 
print(data[idx_2]['class'])

width = 10

plt.figure(figsize=(width,width*2/3)) 
plt.scatter(data[idx]['timediff'], data[idx]['magdiff'], marker = '.')
plt.xlabel('Absolute time differential (|t_i - t_j|)')
plt.ylabel('log|Mag_i - Mag_j|')
plt.title('CV Structure Function')

plt.figure(figsize=(width,width*2/3)) 
plt.scatter(data[idx_2]['timediff'], data[idx_2]['magdiff'], marker = '.')
plt.xlabel('Absolute time differential (|t_i - t_j|)')
plt.ylabel('log|Mag_i - Mag_j|')
plt.title('Blazar Structure Function')
# Out:
# CV
# Blazar

# %%
#l = len(data)
#labels = ['a']*l
#magdiff = [[]]*l
#timediff = [[]]*l

#data_prim = {'label':[]}
#data_prim = {}

n_components = 30

for i in range(0,10):
    #labels[i] = data[i]['class']
    #magdiff[i] = data[i]['magdiff']
    #timediff[i] = data[i]['timediff']
    #data_prim.update({i:timediff[i][1:100]})
    
    magdiff[i] = data[i]['magdiff']
    
    pca = PCA(n_components=n_components).fit(train)
    
    

train = pd.DataFrame(data = data_prim)

# %%
## PROBLEM!!!
# STRUCTURE FUNCTION does not have same number of parameters always!!!


# Invoke SKlearn's PCA method
n_components = 30
pca = PCA(n_components=n_components).fit(train)

print(pca)

#eigenvalues = pca.components_.reshape(n_components, 28, 28)

# Extracting the PCA components ( eignevalues )
#eigenvalues = pca.components_.reshape(n_components, 28, 28)
eigenvalues = pca.components_
# Out:
# PCA(copy=True, iterated_power='auto', n_components=30, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
eigenvalues.shape
# Out:
# (30, 794)

# %%
n_row = 4
n_col = 7

# Plot the first 8 eignenvalues
plt.figure(figsize=(13,12))
for i in list(range(n_row * n_col)):
#     for offset in [10, 30,0]:
#     plt.subplot(n_row, n_col, i + 1)
    offset =0
    plt.subplot(n_row, n_col, i + 1)
    plt.imshow(eigenvalues[i].reshape(28,28), cmap='jet')
    title_text = 'Eigenvalue ' + str(i + 1)
    plt.title(title_text, size=6.5)
    plt.xticks(())
    plt.yticks(())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-483199fac898> in <module>()
#       9     offset =0
#      10     plt.subplot(n_row, n_col, i + 1)
# ---> 11     plt.imshow(eigenvalues[i].reshape(28,28), cmap='jet')
#      12     title_text = 'Eigenvalue ' + str(i + 1)
#      13     plt.title(title_text, size=6.5)
#
# ValueError: cannot reshape array of size 794 into shape (28,28)
